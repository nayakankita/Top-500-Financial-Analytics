# %%
import pandas as pd

# %%
df = pd.read_csv('E:/INEURON PROJECTS/Financial-Analysis/top500.csv')

# %%
df.head()
# Out:
#    S.No            Name  Mar Cap - Crore  Sales Qtr - Crore  Unnamed: 4
# 0     1  Reliance Inds.        583436.72           99810.00         NaN
# 1     2             TCS        563709.84           30904.00         NaN
# 2     3       HDFC Bank        482953.59           20581.27         NaN
# 3     4             ITC        320985.27            9772.02         NaN
# 4     5         H D F C        289497.37           16840.51         NaN

# %%
df.drop(columns=['S.No','Unnamed: 4'],axis=1,inplace=True)

# %%
df.head()
# Out:
#              Name  Mar Cap - Crore  Sales Qtr - Crore
# 0  Reliance Inds.        583436.72           99810.00
# 1             TCS        563709.84           30904.00
# 2       HDFC Bank        482953.59           20581.27
# 3             ITC        320985.27            9772.02
# 4         H D F C        289497.37           16840.51

# %%
df.index = df.index+1

# %%
df.index.rename('SNo',inplace=True)

# %%
df.rename(columns={'Mar Cap - Crore':'Mar-cap','Sales Qtr - Crore':'Sales-qtr'},inplace=True)

# %%
df
# Out:
#                 Name    Mar-cap  Sales-qtr
# SNo
# 1     Reliance Inds.  583436.72   99810.00
# 2                TCS  563709.84   30904.00
# 3          HDFC Bank  482953.59   20581.27
# 4                ITC  320985.27    9772.02
# 5            H D F C  289497.37   16840.51
# ..               ...        ...        ...
# 484  Lak. Vilas Bank    3029.57     790.17
# 485            NOCIL    3026.26     249.27
# 486    Orient Cement    3024.32     511.53
# 487  Natl.Fertilizer    3017.07    2840.75
# 488        L T Foods        NaN        NaN
#
# [488 rows x 3 columns]

# %%
df.describe()
# Out:
#              Mar-cap      Sales-qtr
# count     479.000000     365.000000
# mean    28043.857119    4395.976849
# std     59464.615831   11092.206185
# min      3017.070000      47.240000
# 25%      4843.575000     593.740000
# 50%      9885.050000    1278.300000
# 75%     23549.900000    2840.750000
# max    583436.720000  110666.930000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 488 entries, 1 to 488
# Data columns (total 3 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               488 non-null    object
#  1   Mar Cap - Crore    479 non-null    float64
#  2   Sales Qtr - Crore  365 non-null    float64
# dtypes: float64(2), object(1)
# memory usage: 11.6+ KB

# %%
df.shape
# Out:
# (488, 3)

# %%
df['Mar-cap'].max()
# Out:
# 583436.72

# %% [markdown]
# ### Company with Highest and Lowest Market Cap

# %%
df.loc[df['Mar-cap']==df['Mar-cap'].max(),:]
# Out:
#                Name    Mar-cap  Sales-qtr
# SNo
# 1    Reliance Inds.  583436.72    99810.0

# %%
df.loc[df['Mar-cap']==df['Mar-cap'].min(),:]
# Out:
#                 Name  Mar-cap  Sales-qtr
# SNo
# 487  Natl.Fertilizer  3017.07    2840.75

# %% [markdown]
# ### Company with Highest and Lowest Quaterly Sale

# %%
df.loc[df['Sales-qtr']==df['Sales-qtr'].max(),:]
# Out:
#         Name    Mar-cap  Sales-qtr
# SNo
# 15   I O C L  178017.48  110666.93

# %%
df.loc[df['Sales-qtr']==df['Sales-qtr'].min(),:]
# Out:
#                  Name  Mar-cap  Sales-qtr
# SNo
# 468  Central Dep. Ser  3316.31      47.24

# %% [markdown]
# ### Market Cap to Sale Ratio(Highest and Lowest)

# %%
df['Ratio'] = df['Mar-cap']/df['Sales-qtr']
df.head()
# Out:
#                Name    Mar-cap  Sales-qtr      Ratio
# SNo
# 1    Reliance Inds.  583436.72   99810.00   5.845474
# 2               TCS  563709.84   30904.00  18.240676
# 3         HDFC Bank  482953.59   20581.27  23.465685
# 4               ITC  320985.27    9772.02  32.847382
# 5           H D F C  289497.37   16840.51  17.190535

# %%
df.loc[df['Ratio']==df['Ratio'].max(),:]
# Out:
#                  Name  Mar-cap  Sales-qtr      Ratio
# SNo
# 468  Central Dep. Ser  3316.31      47.24  70.201312

# %%
df.loc[df['Ratio']==df['Ratio'].min(),:]
# Out:
#                 Name  Mar-cap  Sales-qtr     Ratio
# SNo
# 321  Redington India  5896.54    11728.4  0.502757

# %% [markdown]
# ### Market Segmentation

# %%
df['USD'] = round(df['Mar-cap']/82.60,2)
df.head()
# Out:
#                Name    Mar-cap  Sales-qtr      Ratio      USD
# SNo
# 1    Reliance Inds.  583436.72   99810.00   5.845474  7063.40
# 2               TCS  563709.84   30904.00  18.240676  6824.57
# 3         HDFC Bank  482953.59   20581.27  23.465685  5846.90
# 4               ITC  320985.27    9772.02  32.847382  3886.02
# 5           H D F C  289497.37   16840.51  17.190535  3504.81

# %% [markdown]
# ### Large Cap(Market value > 10 billion $ and <200 billion $)

# %%
df.query('USD>1000')
# Out:
#                  Name    Mar-cap  Sales-qtr      Ratio      USD
# SNo
# 1      Reliance Inds.  583436.72   99810.00   5.845474  7063.40
# 2                 TCS  563709.84   30904.00  18.240676  6824.57
# 3           HDFC Bank  482953.59   20581.27  23.465685  5846.90
# 4                 ITC  320985.27    9772.02  32.847382  3886.02
# 5             H D F C  289497.37   16840.51  17.190535  3504.81
# 6      Hind. Unilever  288265.26    8590.00  33.558237  3489.89
# 7       Maruti Suzuki  263493.81   19283.20  13.664423  3190.00
# 8             Infosys  248320.35   17794.00  13.955285  3006.30
# 9             O N G C  239981.50   22995.88  10.435848  2905.35
# 10     St Bk of India  232763.33   57014.08   4.082559  2817.96
# 11         ICICI Bank  203802.35   13665.35  14.913804  2467.34
# 12    Kotak Mah. Bank  199253.77    6390.71  31.178659  2412.27
# 13         Coal India  192677.98   21643.28   8.902439  2332.66
# 14    Larsen & Toubro  180860.74   28747.45   6.291366  2189.60
# ...

# %% [markdown]
# ### Midcap Companies

# %%
df.query('USD>200 & USD <1000')
# Out:
#                  Name   Mar-cap  Sales-qtr      Ratio     USD
# SNo
# 34        Adani Ports  81781.89    2688.85  30.415192  990.10
# 35      Bajaj Finserv  79795.11    7665.40  10.409778  966.04
# 36       GAIL (India)  78670.97   14414.34   5.457827  952.43
# 37      Avenue Super.  74066.35    4094.82  18.087816  896.69
# 38      Titan Company  73886.00    4274.84  17.283922  894.50
# ..                ...       ...        ...        ...     ...
# 156           MphasiS  16728.78    1660.69  10.073391  202.53
# 157  Apollo Hospitals  16683.97    1896.14   8.798913  201.99
# 158  Reliance Nip.Lif  16655.58     394.00  42.273046  201.64
# 159       Tata Global  16589.24    1730.39   9.586995  200.84
# 160   Godrej Propert.  16545.51     627.03  26.387111  200.31
#
# [125 rows x 5 columns]
